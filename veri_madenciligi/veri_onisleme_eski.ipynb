# %%
import pandas as pd
import numpy as np

# %%
veri = pd.read_excel("olimpiyat.xlsx",sheet_name="ilk")
veri
# Out:
#                                  isim cinsiyet  yas     boy   kilo       spor
# 0             Slvia Domnguez Fernndez        K   29   167.0    NaN  Basketbol
# 1                  Usman Edu Muhammed        E   22   169.0   78.0     Futbol
# 2                 Popoola Sodiq Saliu        E   21   170.0   51.0     Futbol
# 3           Okechukwu Godson Azubuike        E   19   170.0   68.0     Futbol
# 4                       Tamara Radoaj        K   28   170.0    NaN  Basketbol
# 5                       Julian Brandt        E   20   183.0   83.0     Futbol
# 6                         Sven Bender        E   27   185.0   80.0     Futbol
# 7            Wverton Pereira da Silva        E   28   189.0   86.0     Futbol
# 8                       Tijana Bokovi        K   19   193.0   82.0   Voleybol
# 9        Maurcio Borges Almeida Silva        E   27   199.0   99.0   Voleybol
# 10               Evandro Motta Guerra        E   34   207.0  106.0   Voleybol
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   isim      21 non-null     object
#  1   cinsiyet  21 non-null     object
#  2   yas       21 non-null     int64
#  3   boy       16 non-null     float64
#  4   kilo      19 non-null     float64
#  5   spor      21 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
print(veri.describe())
print(veri.boy.describe()[5])
boy_ortanca=veri.boy.describe()[5]
kilo_ortanca=veri.kilo.describe()[5]
# Out:
#              yas          boy        kilo
# count  21.000000    16.000000   19.000000
# mean   28.571429   291.000000   84.789474
# std    10.892986   408.058656   13.750066
# min    19.000000   167.000000   51.000000
# 25%    23.000000   170.000000   79.000000
# 50%    27.000000   191.000000   86.000000
# 75%    29.000000   208.000000   94.000000
# max    72.000000  1820.000000  106.000000
# 191.0

# %%
veri_temiz=veri.copy()
veri_temiz.boy.fillna(boy_ortanca,inplace=True)
veri_temiz.kilo.fillna(kilo_ortanca,inplace=True)
print(veri.info())
print(veri_temiz.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   isim      21 non-null     object
#  1   cinsiyet  21 non-null     object
#  2   yas       21 non-null     int64
#  3   boy       16 non-null     float64
#  4   kilo      19 non-null     float64
#  5   spor      21 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   isim      21 non-null     object
#  1   cinsiyet  21 non-null     object
#  2   yas       21 non-null     int64
#  3   boy       21 non-null     float64
#  4   kilo      21 non-null     float64
#  5   spor      21 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.1+ KB
# None
